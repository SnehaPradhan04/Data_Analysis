# %% [markdown]
# <a href="https://colab.research.google.com/github/SnehaPradhan04/Data_Analysis/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve         6.0
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista         0.0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado         0.0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado         0.0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening         0.0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0     126903.0       0.0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1      98200.0       0.0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2     181640.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3     176907.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4     163080.0       0.0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450  0.0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695  0.2630  0.0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434  0.1770  1.0   -21.180   1.0       0.0512
# 3   1922-03-21         0.321  0.0946  7.0   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %%
pd.isnull(df_tracks).sum()
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143922 entries, 1922-02-22 to nan
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                143922 non-null  object
#  1   name              143922 non-null  object
#  2   popularity        143921 non-null  float64
#  3   duration_ms       143921 non-null  float64
#  4   explicit          143921 non-null  float64
#  5   artists           143921 non-null  object
#  6   id_artists        143921 non-null  object
#  7   danceability      143921 non-null  float64
#  8   energy            143921 non-null  float64
#  9   key               143921 non-null  float64
#  10  loudness          143921 non-null  float64
#  11  mode              143921 non-null  float64
#  12  speechiness       143921 non-null  float64
#  13  acousticness      143921 non-null  float64
#  14  instrumentalness  143921 non-null  float64
#  15  liveness          143921 non-null  float64
#  16  valence           143921 non-null  float64
#  17  tempo             143921 non-null  float64
#  18  time_signature    143921 non-null  float64
# dtypes: float64(15), object(4)
# memory usage: 22.0+ MB

# %%
sorted_df = df_tracks.sort_values('popularity', ascending = True).head(10)
sorted_df

df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        143921.0      27.967538      23.531190     0.0       2.0000
# duration_ms       143921.0  231391.292098  139799.749238  3344.0  169060.0000
# explicit          143921.0       0.039397       0.194537     0.0       0.0000
# danceability      143921.0       0.543951       0.171279     0.0       0.4260
# energy            143921.0       0.478437       0.263506     0.0       0.2580
# key               143921.0       5.187888       3.501608     0.0       2.0000
# loudness          143921.0     -11.458615       5.521186   -60.0     -14.5270
# mode              143921.0       0.698654       0.458844     0.0       0.0000
# speechiness       143921.0       0.097965       0.170644     0.0       0.0348
# acousticness      143921.0       0.529954       0.374353     0.0       0.1280
# instrumentalness  143921.0       0.183144       0.324955     0.0       0.0000
# liveness          143921.0       0.206626       0.174924     0.0       0.0987
# valence           143921.0       0.538982       0.262762     0.0       0.3280
# tempo             143921.0     116.753928      30.048644     0.0      94.0140
# time_signature    143921.0       3.857394       0.498059     0.0       4.0000
#
#                             50%          75%          max
# popularity            27.000000      47.0000      100.000
# duration_ms       205173.000000  262840.0000  5042185.000
# explicit               0.000000       0.0000        1.000
# danceability           0.557000       0.6720        0.988
# energy                 0.460000       0.6930        1.000
# key                    5.000000       8.0000       11.000
# loudness             -10.576000      -7.3360        4.584
# mode                   1.000000       1.0000        1.000
# speechiness            0.044600       0.0718        0.970
# acousticness           0.586000       0.9110        0.996
# instrumentalness       0.000343       0.1740        1.000
# liveness               0.137000       0.2630        1.000
# valence                0.552000       0.7610        1.000
# tempo                115.298000     134.4820      243.507
# time_signature         4.000000       4.0000        5.000

# %%
most_popular = df_tracks.query('popularity > 90', inplace = False).sort_values('popularity', ascending = False)
most_popular[:10]
# Out:
#                                   id                                    name  \
# release_date
# 2021-03-19    4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 2021-01-08    7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2021-01-06    3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 2020-03-20    5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 2020-12-04    6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 2020-03-20    0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 2021-03-05    7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 2020-09-16    6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 2019-11-07    60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 2020-03-27    3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#               popularity  duration_ms  explicit  \
# release_date
# 2021-03-19         100.0     198082.0       1.0
# 2021-01-08          99.0     242014.0       1.0
# 2021-01-06          98.0     132780.0       0.0
# 2020-03-20          97.0     215627.0       1.0
# 2020-12-04          97.0     160191.0       0.0
# 2020-03-20          96.0     200040.0       0.0
# 2021-03-05          96.0     242096.0       0.0
# 2020-09-16          95.0     164000.0       0.0
# 2019-11-07          94.0     226987.0       1.0
# 2020-03-27          94.0     198371.0       0.0
#
#                                                      artists  \
# release_date
# 2021-03-19      ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 2021-01-08                                ['Olivia Rodrigo']
# 2021-01-06                                   ['Masked Wolf']
# 2020-03-20                                    ['The Weeknd']
# 2020-12-04                                    ['Kali Uchis']
# 2020-03-20                                    ['The Weeknd']
# 2021-03-05    ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']
# 2020-09-16                                        ['Tiësto']
# 2019-11-07                                      ['Doja Cat']
# 2020-03-27                                        ['Giveon']
#
#                                                      id_artists  danceability  \
# release_date
# 2021-03-19    ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...         0.677
# 2021-01-08                           ['1McMsnEElThX1knmY4oliG']         0.585
# 2021-01-06                           ['1uU7g3DNSbsu0QjSEqZtEd']         0.778
# 2020-03-20                           ['1Xyo4u8uXC1ZmMpatF05PJ']         0.680
# 2020-12-04                           ['1U1el3k54VvEUzo3ybLPlM']         0.653
# 2020-03-20                           ['1Xyo4u8uXC1ZmMpatF05PJ']         0.514
# 2021-03-05    ['0du5cEVh5yTK9QJze8zA0C', '3jK9MiCrA42lLAdMGU...         0.586
# 2020-09-16                           ['2o5jDhtHVPhrJdv3cEQ99Z']         0.798
# 2019-11-07                           ['5cj0lLjcoR7YOSnhnX0Po5']         0.749
# 2020-03-27                           ['4fxd5Ee7UefO4CUXgwJ7IP']         0.449
#
#               energy   key  loudness  mode  speechiness  acousticness  \
# release_date
# 2021-03-19     0.696   0.0    -6.181   1.0       0.1190       0.32100
# 2021-01-08     0.436  10.0    -8.761   1.0       0.0601       0.72100
# 2021-01-06     0.695   4.0    -6.865   0.0       0.0913       0.17500
# 2020-03-20     0.826   0.0    -5.487   1.0       0.0309       0.02120
# 2020-12-04     0.524  11.0    -9.016   0.0       0.0502       0.11200
# 2020-03-20     0.730   1.0    -5.934   1.0       0.0598       0.00146
# 2021-03-05     0.616   5.0    -7.964   1.0       0.0324       0.18200
# 2020-09-16     0.620   8.0    -7.079   0.0       0.2320       0.41400
# 2019-11-07     0.463  11.0    -8.433   1.0       0.0828       0.20800
# 2020-03-27     0.465   0.0    -8.964   1.0       0.0791       0.52400
#
#               instrumentalness  liveness  valence    tempo  time_signature
# release_date
# 2021-03-19            0.000000    0.4200    0.464   90.030             4.0
# 2021-01-08            0.000013    0.1050    0.132  143.874             4.0
# 2021-01-06            0.000000    0.1500    0.472  149.996             4.0
# 2020-03-20            0.000012    0.5430    0.644  118.051             4.0
# 2020-12-04            0.000000    0.2030    0.553   83.970             4.0
# 2020-03-20            0.000095    0.0897    0.334  171.005             4.0
# 2021-03-05            0.000000    0.0927    0.719  148.088             4.0
# 2020-09-16            0.019200    0.1120    0.235  120.031             4.0
# 2019-11-07            0.037100    0.3370    0.190   90.028             4.0
# 2020-03-27            0.000001    0.3030    0.543   89.087             3.0

# %%
df_tracks.set_index("release_date", inplace = True)
df_tracks.index = pd.to_datetime(df_tracks.index)
df_tracks.head()

# %%
df_tracks[["artists"]].iloc[18]

# %%
df_tracks["duration"] = df_tracks["duration_ms"].apply(lambda x: round(x/1000))
df_tracks.drop("duration_ms", inplace = True, axis = 1)

df_tracks.duration.head()

# %%
corr_df = df_tracks.drop(["key", "mode","explicit"], axis = 1).corr(method = "pearson")
plt.figure(figsize = (14,6))
heatmap = sns.heatmap(corr_df, annot = True, fmt =".1g" , vmin = -1, vmax = 1, center = 0, cmap = "inferno", linewidths = 1, linecolor = "Black")
heatmap.set_title("Correlation HeatMap Between Variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation = 90)

sample_df = df_tracks.sample(int(0.004*len(df_tracks)))
print(len(sample_df))

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = sample_df, y = "loudness", x = "energy", color = "c").set(title = "loudness vs energy correlation")
plt.figure(figsize=(10,6))
sns.regplot(data = sample_df, y = "popularity", x = "acousticness", color = "c").set(title = "popularity vs acousticness Correlation")

df_tracks['dates'] = df_tracks.index.get_level_values('release_date')
df_tracks.dates = pd.to_datetime(df_tracks.dates)
years = df_tracks.dates.dt.year

# %%
sns.displot(years, discrete = True, aspect =2, height = 5, kind="hist").set(title = "Number of songs per year")

total_dr = df_tracks.duration
fig_dims = (18,7)
fig, ax = plt.subplots(figsize = fig_dims)
fig_dims = sns.barplot(x = years, y = total_dr, ax = ax, errwidth = False).set(title = "Year vs Duration")
plt.xticks(rotation=60)

total_dr = df_tracks.duration
sns.set_style(style = "whitegrid")
fig_dims = (10, 5)
fig, ax = plt.subplots(figsize = fig_dims)
fig = sns.lineplot(x = years, y = total_dr, ax = ax).set(title = "Year vs Duration")

# %%
df_genre = pd.read_csv("SpotifyFeatures.csv")
df_genre.head()

plt.title("Duration of the Songs in Different Genres")
sns.color_palette("rocket", as_cmap = True)
sns.barplot(y='genre', x='duration_ms', data = df_genre)
plt.xlabel("Duration in milliseconds")
plt.ylabel("Genres")

sns.set_style(style = 'darkgrid')
plt.figure(figsize = (10,5))
famous = df_genre.sort_values("popularity", ascending = False).head(10)
sns.barplot(y='genre', x = 'popularity', data = famous).set(title= "Top 5 genres by popularity")
